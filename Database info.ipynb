# %%
import pandas as pd

# %%
df = pd.read_csv('viveros.csv')
df
# Out:
#          Fecha         Direccion Envase  Piezas        Especie
# 0     16/05/19               NaN              1       MEZQUITE
# 1     08/01/19  NUEVA CANDELARIA      8       1  PALMA ABANICO
# 2     08/01/19               NaN      2       1        GUAYABO
# 3     08/01/19               NaN      4       1        CIRUELO
# 4     08/01/19               NaN      4       1        DURAZNO
# ...        ...               ...    ...     ...            ...
# 1834  10/11/19  BARRANCA REFUGIO     15       6     PINO PIÑON
# 1835  10/11/19               NaN      4       8        CIRUELO
# 1836  10/11/19               NaN      4       4        DURAZNO
# 1837  10/11/19               NaN      4       6        MANZANA
# 1838  10/11/19               NaN      8       6    PINO GREGGI
#
# [1839 rows x 5 columns]

# %%
df.count()
# Out:
# Fecha        1839
# Direccion    1256
# Envase       1838
# Piezas       1839
# Especie      1839
# dtype: int64

# %%
df.set_index(['Piezas', 'Especie']).count(level='Especie')
# Out:
#                    Fecha  Direccion  Envase
# Especie
# ACACIA                 2          1       2
# AGUACATE              28          9      28
# ALAMILLO               5          4       5
# ALAMO                 10          8      10
# ALISSO                 3          2       3
# ...                  ...        ...     ...
# TULIPAN MAJAHUA       31         20      31
# VARA DE SAN PEDRO    110         82     110
# VARADUZ                1          1       1
# YUCA                   1          1       1
# ZARCIGUIL              1          0       1
#
# [94 rows x 3 columns]

# %%
for _, item in df.iterrows():
    print(item['Envase'] != (None or '' or ' '))
# Out:
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
